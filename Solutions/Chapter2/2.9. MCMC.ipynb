# %% [markdown]
# ### Solution 1

# %%
import itertools

import numpy as np
import matplotlib.pyplot as plt

# %%
# a) 
n = 5000

xs = np.random.uniform(-1, 1, n)
ys = np.random.uniform(-1, 1, n)

dists = np.sqrt(xs**2 + ys**2)

inside_circle = dists<=1
outside_circle = dists>1

print(f"Empirically, The ratio of points inside circle: {np.mean(inside_circle):.4f}")
print(f"Theorically, The ratio of points inside circle: {np.pi/4:.4f}")

plt.figure(figsize=(5,5))
plt.scatter(xs[inside_circle], ys[inside_circle], color='red', alpha=0.5)
plt.scatter(xs[outside_circle], ys[outside_circle], color='blue', alpha=0.5)
plt.legend(['inside circle', 'outside circlr'])
plt.show()
# Out:
# Empirically, The ratio of points inside circle: 0.7970
# Theorically, The ratio of points inside circle: 0.7854

# %%
# %%time
# b)
dist = []
point1 = np.array([pair[0] for pair in itertools.combinations(zip(xs[inside_circle], ys[inside_circle]), 2)])
point2 = np.array([pair[1] for pair in itertools.combinations(zip(xs[inside_circle], ys[inside_circle]), 2)])
diff = point1 - point2
distances = (diff**2).sum(axis=1)
# Out:
# CPU times: user 6.73 s, sys: 696 ms, total: 7.43 s
# Wall time: 5.8 s

# %%
plt.hist(distances)
plt.show()
